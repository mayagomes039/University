# %%
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import optuna
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.discriminant_analysis import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from sklearn.feature_selection import VarianceThreshold
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import f1_score



# Cell 2: Carregamento dos dados
data = pd.read_csv('/home/cid34senhas/Desktop/DAATP/Entrega/2_data_Random_Forest_Clean.csv') 

# Separação das features e do target
X = data.drop('Transition', axis=1)
y = data['Transition']

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 500)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])
    max_depth = trial.suggest_int('max_depth', 5, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 100)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    bootstrap = trial.suggest_categorical('bootstrap', [False, True])
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])


    model1 = RandomForestClassifier(
        n_estimators=n_estimators,
        max_features=max_features,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=34,
        bootstrap=bootstrap,
        class_weight=class_weight
    )

    scores_5 = cross_val_score(model1, X, y, cv=5, scoring='f1_macro')
    accuracy_5 = scores_5.mean()

    return accuracy_5

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler())
study.optimize(objective, n_trials=300)
print(f"Melhor F1_Score: {study.best_value}")
print(f"Melhores hiperparâmetros: {study.best_params}")
# Out:
# [I 2025-01-18 23:02:34,874] A new study created in memory with name: no-name-79ddd099-5eaf-4783-9eb3-e1f638a3bf23
# [I 2025-01-18 23:02:37,557] Trial 0 finished with value: 0.2961265298308776 and parameters: {'n_estimators': 282, 'max_features': 'log2', 'max_depth': 17, 'min_samples_split': 63, 'min_samples_leaf': 17, 'bootstrap': True, 'class_weight': None}. Best is trial 0 with value: 0.2961265298308776.
# [I 2025-01-18 23:02:39,895] Trial 1 finished with value: 0.3065832890213004 and parameters: {'n_estimators': 237, 'max_features': 'log2', 'max_depth': 42, 'min_samples_split': 57, 'min_samples_leaf': 10, 'bootstrap': False, 'class_weight': None}. Best is trial 1 with value: 0.3065832890213004.
# [I 2025-01-18 23:02:41,692] Trial 2 finished with value: 0.30402964002361654 and parameters: {'n_estimators': 138, 'max_features': 'sqrt', 'max_depth': 50, 'min_samples_split': 31, 'min_samples_leaf': 17, 'bootstrap': True, 'class_weight': None}. Best is trial 1 with value: 0.3065832890213004.
# [I 2025-01-18 23:02:44,669] Trial 3 finished with value: 0.3002501062233386 and parameters: {'n_estimators': 458, 'max_features': 'log2', 'max_depth': 13, 'min_samples_split': 87, 'min_samples_leaf': 4, 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 1 with value: 0.3065832890213004.
# [I 2025-01-18 23:02:46,672] Trial 4 finished with value: 0.3268118577075099 and parameters: {'n_estimators': 227, 'max_features': 'sqrt', 'max_depth': 20, 'min_samples_split': 75, 'min_samples_leaf': 11, 'bootstrap': False, 'class_weight': None}. Best is trial 4 with value: 0.3268118577075099.
# [I 2025-01-18 23:02:50,166] Trial 5 finished with value: 0.33120356659301436 and parameters: {'n_estimators': 436, 'max_features': 'log2', 'max_depth': 8, 'min_samples_split': 39, 'min_samples_leaf': 1, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.33120356659301436.
# [I 2025-01-18 23:02:52,184] Trial 6 finished with value: 0.3207324739352428 and parameters: {'n_estimators': 304, 'max_features': 'sqrt', 'max_depth': 32, 'min_samples_split': 16, 'min_samples_leaf': 19, 'bootstrap': True, 'class_weight': None}. Best is trial 5 with value: 0.33120356659301436.
# [I 2025-01-18 23:02:53,346] Trial 7 finished with value: 0.3042158722992009 and parameters: {'n_estimators': 201, 'max_features': 'sqrt', 'max_depth': 20, 'min_samples_split': 88, 'min_samples_leaf': 10, 'bootstrap': True, 'class_weight': None}. Best is trial 5 with value: 0.33120356659301436.
# [I 2025-01-18 23:02:57,235] Trial 8 finished with value: 0.33930905950642576 and parameters: {'n_estimators': 417, 'max_features': 'sqrt', 'max_depth': 47, 'min_samples_split': 42, 'min_samples_leaf': 7, 'bootstrap': False, 'class_weight': None}. Best is trial 8 with value: 0.33930905950642576.
# [I 2025-01-18 23:02:59,757] Trial 9 finished with value: 0.3003739084347927 and parameters: {'n_estimators': 485, 'max_features': 'log2', 'max_depth': 16, 'min_samples_split': 55, 'min_samples_leaf': 11, 'bootstrap': True, 'class_weight': None}. Best is trial 8 with value: 0.33930905950642576.
# [I 2025-01-18 23:03:04,504] Trial 10 finished with value: 0.3275855058532141 and parameters: {'n_estimators': 361, 'max_features': 'sqrt', 'max_depth': 33, 'min_samples_split': 2, 'min_samples_leaf': 6, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.33930905950642576.
# [I 2025-01-18 23:03:07,366] Trial 11 finished with value: 0.32409783730413977 and parameters: {'n_estimators': 392, 'max_features': 'log2', 'max_depth': 7, 'min_samples_split': 37, 'min_samples_leaf': 1, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.33930905950642576.
# [I 2025-01-18 23:03:10,326] Trial 12 finished with value: 0.32390142032397995 and parameters: {'n_estimators': 410, 'max_features': 'log2', 'max_depth': 41, 'min_samples_split': 37, 'min_samples_leaf': 1, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.33930905950642576.
# [I 2025-01-18 23:03:14,845] Trial 13 finished with value: 0.3648326269031884 and parameters: {'n_estimators': 437, 'max_features': 'sqrt', 'max_depth': 5, 'min_samples_split': 42, 'min_samples_leaf': 6, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:19,085] Trial 14 finished with value: 0.3177672887068925 and parameters: {'n_estimators': 357, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 23, 'min_samples_leaf': 7, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:24,134] Trial 15 finished with value: 0.3429627308172643 and parameters: {'n_estimators': 498, 'max_features': 'sqrt', 'max_depth': 50, 'min_samples_split': 48, 'min_samples_leaf': 7, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:28,219] Trial 16 finished with value: 0.3232447182743189 and parameters: {'n_estimators': 487, 'max_features': 'sqrt', 'max_depth': 30, 'min_samples_split': 69, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:31,741] Trial 17 finished with value: 0.3472517045062772 and parameters: {'n_estimators': 336, 'max_features': 'sqrt', 'max_depth': 36, 'min_samples_split': 50, 'min_samples_leaf': 5, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:34,893] Trial 18 finished with value: 0.3183809482541601 and parameters: {'n_estimators': 337, 'max_features': 'sqrt', 'max_depth': 37, 'min_samples_split': 75, 'min_samples_leaf': 3, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:39,176] Trial 19 finished with value: 0.3551421478209712 and parameters: {'n_estimators': 317, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 12, 'min_samples_leaf': 5, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:40,794] Trial 20 finished with value: 0.36080454008727864 and parameters: {'n_estimators': 128, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 8, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:42,593] Trial 21 finished with value: 0.33396914162199265 and parameters: {'n_estimators': 153, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 9, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:43,811] Trial 22 finished with value: 0.35881804912942866 and parameters: {'n_estimators': 116, 'max_features': 'sqrt', 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 13 with value: 0.3648326269031884.
# [I 2025-01-18 23:03:45,670] Trial 23 finished with value: 0.3763484578052353 and parameters: {'n_estimators': 169, 'max_features': 'sqrt', 'max_depth': 9, 'min_samples_split': 26, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.3763484578052353.
# [I 2025-01-18 23:03:47,447] Trial 24 finished with value: 0.3665965840310573 and parameters: {'n_estimators': 168, 'max_features': 'sqrt', 'max_depth': 5, 'min_samples_split': 25, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.3763484578052353.
# [I 2025-01-18 23:03:49,125] Trial 25 finished with value: 0.35680434062533106 and parameters: {'n_estimators': 169, 'max_features': 'sqrt', 'max_depth': 5, 'min_samples_split': 26, 'min_samples_leaf': 15, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.3763484578052353.
# [I 2025-01-18 23:03:51,072] Trial 26 finished with value: 0.381166994130578 and parameters: {'n_estimators': 183, 'max_features': 'sqrt', 'max_depth': 10, 'min_samples_split': 23, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:03:52,980] Trial 27 finished with value: 0.36042233421279746 and parameters: {'n_estimators': 182, 'max_features': 'sqrt', 'max_depth': 11, 'min_samples_split': 24, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:03:55,465] Trial 28 finished with value: 0.3381213773572308 and parameters: {'n_estimators': 253, 'max_features': 'sqrt', 'max_depth': 13, 'min_samples_split': 29, 'min_samples_leaf': 16, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:03:57,283] Trial 29 finished with value: 0.30008913756271677 and parameters: {'n_estimators': 270, 'max_features': 'sqrt', 'max_depth': 17, 'min_samples_split': 18, 'min_samples_leaf': 20, 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:03:58,384] Trial 30 finished with value: 0.3560593689516288 and parameters: {'n_estimators': 103, 'max_features': 'sqrt', 'max_depth': 10, 'min_samples_split': 33, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:04:00,338] Trial 31 finished with value: 0.3299246483359063 and parameters: {'n_estimators': 208, 'max_features': 'sqrt', 'max_depth': 5, 'min_samples_split': 44, 'min_samples_leaf': 15, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:04:02,301] Trial 32 finished with value: 0.3734585707750958 and parameters: {'n_estimators': 184, 'max_features': 'sqrt', 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.381166994130578.
# [I 2025-01-18 23:04
 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 93 with value: 0.38504803236673263.
# [I 2025-01-18 23:07:39,084] Trial 154 finished with value: 0.37073583042059977 and parameters: {'n_estimators': 164, 'max_features': 'sqrt', 'max_depth': 29, 'min_samples_split': 26, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 93 with value: 0.38504803236673263.
# [I 2025-01-18 23:07:40,528] Trial 155 finished with value: 0.35474394754077077 and parameters: {'n_estimators': 137, 'max_features': 'sqrt', 'max_depth': 32, 'min_samples_split': 28, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 93 with value: 0.38504803236673263.
# [I 2025-01-18 23:07:42,383] Trial 156 finished with value: 0.363151472869945 and parameters: {'n_estimators': 186, 'max_features': 'sqrt', 'max_depth': 16, 'min_samples_split': 35, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 93 with value: 0.38504803236673263.
# [I 2025-01-18 23:07:44,180] Trial 157 finished with value: 0.35082069726691145 and parameters: {'n_estimators': 167, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 29, 'min_samples_leaf': 11, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 93 with value: 0.38504803236673263.
# ...
# [I 2025-01-18 23:10:09,311] Trial 249 finished with value: 0.36438561474664705 and parameters: {'n_estimators': 161, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 27, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 242 with value: 0.3896438059793962.
# [I 2025-01-18 23:10:10,781] Trial 250 finished with value: 0.39517746656845654 and parameters: {'n_estimators': 143, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:12,366] Trial 251 finished with value: 0.3604958022773719 and parameters: {'n_estimators': 152, 'max_features': 'sqrt', 'max_depth': 22, 'min_samples_split': 35, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:13,772] Trial 252 finished with value: 0.3735681520969639 and parameters: {'n_estimators': 140, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 38, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:15,527] Trial 253 finished with value: 0.38286641565253804 and parameters: {'n_estimators': 161, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 33, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:16,806] Trial 254 finished with value: 0.34199439559578215 and parameters: {'n_estimators': 131, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 33, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': None}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:18,360] Trial 255 finished with value: 0.3511812553263828 and parameters: {'n_estimators': 148, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 36, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:19,440] Trial 256 finished with value: 0.3239874421747677 and parameters: {'n_estimators': 164, 'max_features': 'log2', 'max_depth': 25, 'min_samples_split': 34, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:21,001] Trial 257 finished with value: 0.36210176182380965 and parameters: {'n_estimators': 141, 'max_features': 'sqrt', 'max_depth': 23, 'min_samples_split': 29, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:22,622] Trial 258 finished with value: 0.362050690762041 and parameters: {'n_estimators': 157, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 32, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:24,176] Trial 259 finished with value: 0.3665061662322532 and parameters: {'n_estimators': 149, 'max_features': 'sqrt', 'max_depth': 48, 'min_samples_split': 37, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:25,620] Trial 260 finished with value: 0.3650806220464606 and parameters: {'n_estimators': 133, 'max_features': 'sqrt', 'max_depth': 21, 'min_samples_split': 34, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:26,959] Trial 261 finished with value: 0.31544106587901943 and parameters: {'n_estimators': 163, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 30, 'min_samples_leaf': 13, 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:28,455] Trial 262 finished with value: 0.386696131768567 and parameters: {'n_estimators': 143, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 32, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:29,789] Trial 263 finished with value: 0.3702780705658686 and parameters: {'n_estimators': 126, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 33, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:31,347] Trial 264 finished with value: 0.3713191409192468 and parameters: {'n_estimators': 140, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 28, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:33,049] Trial 265 finished with value: 0.3572846249333349 and parameters: {'n_estimators': 147, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 36, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:37,845] Trial 266 finished with value: 0.3724202443346246 and parameters: {'n_estimators': 462, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 32, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:39,239] Trial 267 finished with value: 0.3779348518270557 and parameters: {'n_estimators': 135, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 30, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:40,768] Trial 268 finished with value: 0.3750041121573042 and parameters: {'n_estimators': 152, 'max_features': 'sqrt', 'max_depth': 23, 'min_samples_split': 35, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:42,221] Trial 269 finished with value: 0.34853346652904565 and parameters: {'n_estimators': 142, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 27, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:43,750] Trial 270 finished with value: 0.3471866772392139 and parameters: {'n_estimators': 155, 'max_features': 'sqrt', 'max_depth': 22, 'min_samples_split': 38, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:45,111] Trial 271 finished with value: 0.3659272384897993 and parameters: {'n_estimators': 132, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 33, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:46,627] Trial 272 finished with value: 0.37175146195239306 and parameters: {'n_estimators': 148, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 30, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:48,112] Trial 273 finished with value: 0.37359140658461587 and parameters: {'n_estimators': 119, 'max_features': 'sqrt', 'max_depth': 28, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:49,175] Trial 274 finished with value: 0.31470546341690653 and parameters: {'n_estimators': 155, 'max_features': 'log2', 'max_depth': 24, 'min_samples_split': 35, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': None}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:51,014] Trial 275 finished with value: 0.371633765003586 and parameters: {'n_estimators': 172, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 26, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:52,491] Trial 276 finished with value: 0.3479176115768244 and parameters: {'n_estimators': 139, 'max_features': 'sqrt', 'max_depth': 23, 'min_samples_split': 29, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:53,968] Trial 277 finished with value: 0.39279363864115024 and parameters: {'n_estimators': 146, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:55,663] Trial 278 finished with value: 0.38568074446515227 and parameters: {'n_estimators': 162, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 31, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:56,874] Trial 279 finished with value: 0.3269222086502107 and parameters: {'n_estimators': 146, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 78, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:10:58,705] Trial 280 finished with value: 0.36786060327423387 and parameters: {'n_estimators': 169, 'max_features': 'sqrt', 'max_depth': 23, 'min_samples_split': 28, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:00,292] Trial 281 finished with value: 0.3683115379150251 and parameters: {'n_estimators': 156, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 31, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:01,314] Trial 282 finished with value: 0.35367948463003895 and parameters: {'n_estimators': 128, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 30, 'min_samples_leaf': 13, 'bootstrap': True, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:06,305] Trial 283 finished with value: 0.35905646948939496 and parameters: {'n_estimators': 476, 'max_features': 'sqrt', 'max_depth': 21, 'min_samples_split': 34, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:07,989] Trial 284 finished with value: 0.3487412560156372 and parameters: {'n_estimators': 146, 'max_features': 'sqrt', 'max_depth': 22, 'min_samples_split': 25, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:11,543] Trial 285 finished with value: 0.35823409206120205 and parameters: {'n_estimators': 319, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 31, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:13,430] Trial 286 finished with value: 0.3615839511696642 and parameters: {'n_estimators': 162, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 28, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:15,079] Trial 287 finished with value: 0.37798747403545013 and parameters: {'n_estimators': 149, 'max_features': 'sqrt', 'max_depth': 28, 'min_samples_split': 36, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:17,007] Trial 288 finished with value: 0.37198068171026477 and parameters: {'n_estimators': 140, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 33, 'min_samples_leaf': 1, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:18,759] Trial 289 finished with value: 0.3669435892776223 and parameters: {'n_estimators': 155, 'max_features': 'sqrt', 'max_depth': 25, 'min_samples_split': 30, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:20,683] Trial 290 finished with value: 0.3514333101629998 and parameters: {'n_estimators': 175, 'max_features': 'sqrt', 'max_depth': 23, 'min_samples_split': 39, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:22,549] Trial 291 finished with value: 0.381460331185254 and parameters: {'n_estimators': 166, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 34, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:24,057] Trial 292 finished with value: 0.37355893735832685 and parameters: {'n_estimators': 135, 'max_features': 'sqrt', 'max_depth': 30, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:25,633] Trial 293 finished with value: 0.3338527207972962 and parameters: {'n_estimators': 153, 'max_features': 'sqrt', 'max_depth': 28, 'min_samples_split': 28, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': None}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:27,060] Trial 294 finished with value: 0.3626776275531898 and parameters: {'n_estimators': 125, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 37, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:28,123] Trial 295 finished with value: 0.319501409353256 and parameters: {'n_estimators': 145, 'max_features': 'log2', 'max_depth': 27, 'min_samples_split': 31, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:30,054] Trial 296 finished with value: 0.37884591816825075 and parameters: {'n_estimators': 160, 'max_features': 'sqrt', 'max_depth': 26, 'min_samples_split': 34, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:31,753] Trial 297 finished with value: 0.34522832363786077 and parameters: {'n_estimators': 143, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 26, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:33,498] Trial 298 finished with value: 0.35853772702393394 and parameters: {'n_estimators': 153, 'max_features': 'sqrt', 'max_depth': 29, 'min_samples_split': 29, 'min_samples_leaf': 14, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# [I 2025-01-18 23:11:35,377] Trial 299 finished with value: 0.367379319420099 and parameters: {'n_estimators': 169, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 32, 'min_samples_leaf': 12, 'bootstrap': False, 'class_weight': 'balanced'}. Best is trial 250 with value: 0.39517746656845654.
# Melhor F1_Score: 0.39517746656845654
# Melhores hiperparâmetros: {'n_estimators': 143, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}

# %% [markdown]
# ### Resultados
# #### Tentativa 1:
# Melhor F1_Score : 0.36041648923638786
#
# Melhores hiperparâmetros: {'n_estimators': 210, 'max_features': 'sqrt', 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 20, 'bootstrap': False}
#
# #### Tentativa 2:
# Melhor F1_Score: 0.35570703695449063
#
# Melhores hiperparâmetros: {'n_estimators': 173, 'max_features': 'sqrt', 'max_depth': 22, 'min_samples_split': 40, 'min_samples_leaf': 11, 'bootstrap': False}
#
# #### Tentativa 3:
# Melhor F1_Score: 0.3708177473272097
#
# Melhores hiperparâmetros: {'n_estimators': 271, 'max_features': 'sqrt', 'max_depth': 27, 'min_samples_split': 50, 'min_samples_leaf': 11, 'bootstrap': False}
#
# ### Tentativa 4:
#
# Melhor F1_Score: 0.39517746656845654
#
# Melhores hiperparâmetros: {'n_estimators': 143, 'max_features': 'sqrt', 'max_depth': 24, 'min_samples_split': 32, 'min_samples_leaf': 13, 'bootstrap': False, 'class_weight': 'balanced'}

# %%
def plot_confusion_matrix_with_labels(confusion_matrix, label_mapping):
    # Criar um mapeamento inverso
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    
    # Aplicar o mapeamento inverso na matriz de confusão
    cm_with_labels = np.zeros_like(confusion_matrix, dtype=object)
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            cm_with_labels[i, j] = f"{reverse_label_mapping[i]} (Pred: {reverse_label_mapping[j]})"

    # Criar um DataFrame para facilitar a visualização
    df_cm = pd.DataFrame(confusion_matrix, index=reverse_label_mapping.values(), columns=reverse_label_mapping.values())
    
    # Plotar a matriz de confusão
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=True, fmt="d", cmap="Blues")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix with Labels')
    plt.show()
label_mapping = {
    'CN-CN': 0,
    'AD-AD': 1,
    'MCI-AD': 2,
    'MCI-MCI': 3,
    'CN-MCI' : 4
}

X_trail = data.drop(['Transition'], axis= 1)
y_trail = data['Transition']

# %%
rf_model_final = RandomForestClassifier(n_estimators=143, max_features = 'sqrt', max_depth= 24, min_samples_split=32, min_samples_leaf=13, bootstrap=False,class_weight = 'balanced',random_state=34)
rf_score = cross_val_score(rf_model_final, X_trail, y_trail, cv=5,scoring='f1_macro')
print(f"Cross Validation Score: {rf_score}")
print(f"Cross Validation Score Média: {rf_score.mean()}")
print(f"Cross Validation Score STD: {rf_score.std()}")
# Out:
# Cross Validation Score: [0.47478261 0.29848841 0.4116514  0.43780664 0.35315827]
# Cross Validation Score Média: 0.39517746656845654
# Cross Validation Score STD: 0.06251400064162042

# %% [markdown]
# ## Gerar CSV para submissão

# %%
def remove_highly_correlated_features(data, target, threshold):
    """
    Remove features altamente correlacionadas, mantendo a que tem maior correlação com o target.

    Args:
        data (pd.DataFrame): DataFrame contendo as features.
        target (pd.Series): Coluna com os valores do target.
        threshold (float): Valor de correlação acima do qual consideramos features altamente correlacionadas.

    Returns:
        pd.DataFrame: DataFrame com as colunas altamente correlacionadas removidas.
        set: Conjunto das colunas removidas.
    """
    # Compute the correlation matrix
    corr_matrix = data.corr().abs()
    
    # Compute correlation of each feature with the target
    target_corr = data.corrwith(data['Transition']).abs()
    
    # Identify columns to remove based on correlation
    to_drop = set()
    for i in range(len(corr_matrix.columns)):
        for j in range(i + 1, len(corr_matrix.columns)):
            if corr_matrix.iloc[i, j] >= threshold:
                col_i = corr_matrix.columns[i]
                col_j = corr_matrix.columns[j]
                
                # Remove the column with lower correlation with the target
                if target_corr[col_i] < target_corr[col_j]:
                    to_drop.add(col_i)
                else:
                    to_drop.add(col_j)

    # Drop the identified columns
    data_final = data.drop(columns=to_drop)

    return data_final, to_drop


def remove_low_variance_features(data, threshold):
    """
    Remove columns with a standard deviation below the given threshold.

    Parameters:
        data (pd.DataFrame): The input DataFrame.
        threshold (float): The minimum standard deviation a column must have to be retained.

    Returns:
        tuple: A tuple containing:
            - pd.DataFrame: A DataFrame with low-variance columns removed.
            - list: A list of columns that were removed.
    """
    # Calculate the standard deviation for each column
    std_dev = data.std()

    # Identify columns to keep (standard deviation above threshold)
    retained_columns = std_dev[std_dev > threshold].index

    # Identify columns to remove
    removed_columns = std_dev[std_dev <= threshold].index

    # Create a new DataFrame with only the retained columns
    data_reduced = data[retained_columns]

    return data_reduced, removed_columns

from sklearn.base import ClassifierMixin

def generate_predictions_csv(model: ClassifierMixin, test_data: pd.DataFrame):
    """
    Gera um arquivo CSV com as previsões do modelo fornecido e o conjunto de teste.

    Parameters:
    - model: Classificador treinado (ex: RandomForestClassifier, DecisionTreeClassifier).
    - test_data: DataFrame de teste para o qual as previsões serão feitas.
    - output_filename: Nome do arquivo de saída para salvar as previsões (padrão é 'predictions.csv').
    """
    # Realizar as previsões
    predictions = model.predict(test_data)
    
    # Mapeamento inverso para converter de números para labels
    label_mapping = {
        0: 'CN-CN',
        1: 'AD-AD',
        2: 'MCI-AD',
        3: 'MCI-MCI',
        4:  'CN-MCI'

    }
    
    # Converter as previsões numéricas para as labels correspondentes
    predictions_labels = [label_mapping[pred] for pred in predictions]
    
    # Criar DataFrame com as previsões
    predictions_df = pd.DataFrame(predictions_labels, columns=['Result'])
    predictions_df.index = range(1, len(predictions_df) + 1)
    predictions_df.index.name = 'RowId'
    
    # Exibir a contagem de cada label prevista
    counts = predictions_df['Result'].value_counts()
    print("Contagem de previsões para cada label:")
    print(counts)
    
    # Extrair o nome do modelo para o arquivo de saída
    model_name = str(model)  
    if '(' in model_name:
        output_filename = model_name.split('(')[0] + ".csv"
    else:
        output_filename = model_name + ".csv"
    
    # Salvar o DataFrame em um arquivo CSV
    predictions_df.to_csv(output_filename, index=True)
    print(f"Resultados salvos no arquivo {output_filename}")

# %%
data_test = pd.read_csv('/home/cid34senhas/Desktop/DAATP/Entrega/1_DF_Test_1_After_Pre_Processamento.csv') 
data_original= pd.read_csv('/home/cid34senhas/Desktop/DAATP/Entrega/1_DF_CN-MCI_1_After_Pre_Processamento.csv') 
X_cleaned, to_drop = remove_highly_correlated_features(data_original, 'Transition', 0.81)
data
data_f = data_test.drop(columns=to_drop,axis=1)

X_cleaned_lV, to_drop_2 = remove_low_variance_features(X_cleaned, 0.005)

data_final = data_f.drop(columns=to_drop_2,axis=1, errors='ignore')

print("Shape Do data_set Final de treino do Random Forest ")
print(data.shape)
print("\n")
print("Shape Do data_set Final de test do Random Forest ")
print(data_final.shape)

X_train, X_test, y_train, y_test = train_test_split(X_trail, y_trail, test_size=0.25, random_state=34, stratify=y)

rf_model_final.fit(X_train,y_train)
generate_predictions_csv(rf_model_final,data_final)
# Out:
# Shape Do data_set Final de treino do Random Forest
# (305, 348)
#
#
# Shape Do data_set Final de test do Random Forest
# (100, 347)
# Contagem de previsões para cada label:
# Result
# CN-CN      42
# AD-AD      27
# MCI-AD     16
# MCI-MCI    13
# CN-MCI      2
# Name: count, dtype: int64
# Resultados salvos no arquivo RandomForestClassifier.csv

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Os resultados obtidos vão contra o esperado, esperavamos resultados perto do f1_macro medio obtido no cross_validation, dentro da baliza do desvio padrão do mesmo. Contudo, como a privada são apenas 30% dos dados de teste, o valor de 0.395177 é o esperado na privada
